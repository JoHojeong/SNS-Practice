# %%
# 네이버 영화 리뷰 및 평점 수집하기

#Step 1. 필요한 모듈과 라이브러리를 로딩합니다.

from bs4 import BeautifulSoup
from selenium import webdriver

import time
import sys
import re
import math
import numpy  
import pandas as pd
import random
import os

#Step 2. 사용자에게 검색어 키워드를 입력 받고 저장할 폴더와 파일명을 설정합니다.
print("-" *80)
print("네이버 영화 리뷰 및 평점 수집하기")
print("=" *80)
print("\n")

query_txt = input('1.크롤링 할 영화의 제목을 입력하세요: ')
query_url = 'https://movie.naver.com'

cnt = int(input('2.크롤링 할 리뷰건수는 몇건입니까?: '))
page_cnt = math.ceil(cnt / 10)

f_dir = input("3.파일을 저장할 폴더명만 쓰세요(예:c:\\temp\\):")

# 저장될 파일위치와 이름을 지정합니다
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

os.makedirs(f_dir+s+'-'+query_txt)
os.chdir(f_dir+s+'-'+query_txt)

ff_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.txt'
fc_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.csv'
fx_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.xls'

#Step 3. 크롬 드라이버를 사용해서 웹 브라우저를 실행합니다.

s_time = time.time( )

path = "c:/practice/chromedriver.exe"
driver = webdriver.Chrome(path)
driver.get(query_url)
time.sleep(3)

# 영화 제목
element = driver.find_element_by_id("ipt_tx_srch")
element.send_keys(query_txt)
driver.find_element_by_xpath("""//*[@id="jSearchArea"]/div/button""").click()
driver.find_element_by_xpath("""//*[@id="old_content"]/ul[2]/li/dl/dt/a""").click()
        
# 평점 클릭
driver.find_element_by_link_text("평점").click()

# 내용 수집
driver.switch_to.frame('pointAfterListIframe')

# 현재 총 리뷰 건수를 확인하여 사용자의 요청건수와 비교 후 동기화

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

result= soup.find('div', class_='score_total').find('strong', class_='total').find_all('em')
result2 = result[0].get_text()

print("=" *80)
result3 = result2.replace(",","")
result4 = re.search("\d+",result3)
search_cnt = int(result4.group())

if cnt > search_cnt :
    cnt = search_cnt

print("전체 검색 결과 건수 :",search_cnt,"건")
print("실제 최종 출력 건수",cnt)

print("\n")
page_cnt = math.ceil(cnt / 10)
print("크롤링 할 총 페이지 번호: ",page_cnt)
print("=" *80)


score2=[]
review2=[]
writer2=[]
write_date2=[]
g_gogam2=[]
b_gogam2=[]

count = 0

# 페이지 번호
click_count = 1  

while ( click_count <= page_cnt )  :  #총 페이지보다 페이지번호가 작거나 같으면 작동
            
            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            
            score_result = soup.find('div', class_='score_result').find('ul')
            slist = score_result.find_all('li')

            for li in slist:

                count += 1
                
                f = open(ff_name, 'a',encoding='UTF-8')
            
                print("\n")
                print("총 %s 건 중 %s 번째 리뷰 데이터를 수집합니다==============" %(cnt,count))
                score = li.find('div', class_='star_score').find('em').get_text()
                print("1.별점:","*"*int(score),": ", score)
                score2.append(score)
                f.write("\n")
                f.write("총 %s 건 중 %s 번째 리뷰 데이터를 수집합니다==============" %(cnt,count) + "\n")
                f.write("1.별점:"+score + "\n")
            
                review = li.find('div', class_='score_reple').find('p').get_text().strip()
                print("2.리뷰내용:",review)
                f.write("2.리뷰내용:" + review + "\n")
                review2.append(review)
         
                dwlist = li.find('div',class_='score_reple').find_all('em')
                writer = dwlist[0].find('span').get_text()
                print("3.작성자:",writer)
                f.write("3.작성자:" + writer + "\n")
                writer2.append(writer)
                
                write_date = dwlist[1].text
                print('4.작성일자:',write_date)
                f.write("4.작성일자:" + write_date + "\n")
                write_date2.append(write_date)
            
                gogam = li.find('div', class_='btn_area').find_all('strong')
                g_gogam = gogam[0].text
                print('5.공감:',g_gogam)
                f.write("5.공감:" + g_gogam + "\n")
                g_gogam2.append(g_gogam)
                
                b_gogam = gogam[1].text
                print('6.비공감:', b_gogam)
                f.write("6.비공감:" + b_gogam + "\n")
                b_gogam2.append(b_gogam)
                
                print("\n")

                
                if count == cnt :
                    break
            
            time.sleep(random.randrange(3,8))  

            click_count += 1
            
            if click_count > page_cnt :
                break
            else :
                driver.find_element_by_link_text("%s" %click_count).click()

            time.sleep(random.randrange(3,8))  # 3-8 초 사이에 랜덤으로 시간 선택


# xls 형태와 csv 형태로 저장하기
naver_movie = pd.DataFrame()
naver_movie['별점(평점)']=score2
naver_movie['리뷰내용']=review2
naver_movie['작성자']=writer2
naver_movie['작성일자']=write_date2
naver_movie['공감횟수']=g_gogam2
naver_movie['비공감횟수']=b_gogam2

# csv 형태로 저장하기
naver_movie.to_csv(fc_name,encoding="utf-8-sig",index=True)

# 엑셀 형태로 저장하기
naver_movie.to_excel(fx_name ,index=True)

# 요약 정보 출력하기

e_time = time.time( )
t_time = e_time - s_time


print("\n") 
print("=" *80)
print("1.요청된 총 %s 건의 리뷰 중에서 실제 크롤링 된 리뷰수는 %s 건입니다" %(cnt,count))
print("2.총 소요시간은 %s 초 입니다 " %round(t_time,1))
print("3.파일 저장 완료: txt 파일명 : %s " %ff_name)
print("4.파일 저장 완료: csv 파일명 : %s " %fc_name)
print("5.파일 저장 완료: xls 파일명 : %s " %fx_name)
print("=" *80)

driver.close( )
# Out:
# --------------------------------------------------------------------------------
# 네이버 영화 리뷰 및 평점 수집하기
# ================================================================================
#
#
# 1.크롤링 할 영화의 제목을 입력하세요: 7번방의 선물
# 2.크롤링 할 리뷰건수는 몇건입니까?: 20
# 3.파일을 저장할 폴더명만 쓰세요(예:c:\temp\):c:\practice\
# ================================================================================
# 전체 검색 결과 건수 : 44602 건
# 실제 최종 출력 건수 20
#
#
# 크롤링 할 총 페이지 번호:  2
# ================================================================================
#
#
# 총 20 건 중 1 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 영화는 뻔했고 설정은 억지였다 하지만 그걸 살려낸 배우들이 대단한영화.  그중심엔 류승룡이있었다
# 3.작성자: 서준현(gmbs****)
# 4.작성일자: 2013.06.06 06:13
# 5.공감: 1854
# 6.비공감: 471
#
#
#
#
# 총 20 건 중 2 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ******* :  7
# 2.리뷰내용: 천만영화의 부끄러운 실체. 배우들간의 앙상블은 훌륭했으나 작위적이고 평면적인 스토리, 후반부 쥐어짜는 신파극. 어쩔 수 없이 눈물이 난다.
# 3.작성자: tang****
# 4.작성일자: 2013.06.10 19:28
# 5.공감: 1932
# 6.비공감: 731
#
#
#
#
# 총 20 건 중 3 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ******* :  7
# 2.리뷰내용: 천만관객을 끌어모은 것은 오직 배우들의 힘.
# 3.작성자: kthy****
# 4.작성일자: 2013.06.03 21:04
# 5.공감: 1569
# 6.비공감: 392
#
#
#
#
# 총 20 건 중 4 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ******** :  8
# 2.리뷰내용: 뜬금없는 열기구...
# 3.작성자: OSㅡEOS(hyun****)
# 4.작성일자: 2013.07.14 17:34
# 5.공감: 1427
# 6.비공감: 339
#
#
#
#
# 총 20 건 중 5 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 연기 정말 장난아님
# 3.작성자: 한영(limj****)
# 4.작성일자: 2013.06.06 23:35
# 5.공감: 1208
# 6.비공감: 180
#
#
#
#
# 총 20 건 중 6 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ******* :  7
# 2.리뷰내용: 예승이가 감옥으로 들어오는 설정부터가 조금은 억지가아닌가 싶었지만, 영화 특유의 따뜻한 느낌이 너무좋았습니다. 류승룡씨의 명연기도 잘 봤습니다. 다만 아쉬운점은 한국영화 특유의 눈물 쥐어짜기에서 상업영화의 한계를 보...
# 3.작성자: 김쫑(rla9****)
# 4.작성일자: 2013.07.20 00:11
# 5.공감: 1051
# 6.비공감: 214
#
#
#
#
# 총 20 건 중 7 번째 리뷰 데이터를 수집합니다==============
# 1.별점: **** :  4
# 2.리뷰내용: 보는 내내 기분 더러워지는 영화. 공권력의 수장의 딸이 죽었다는 이유로 모든 증거가 아무 소용이 없게 되고 재판전에 피의자를 피해자측 사람이 만난다는거 자체가 뻥에 국선변호사들 쓰레기 만드는 영화
# 3.작성자: v3ch****
# 4.작성일자: 2013.06.06 10:49
# 5.공감: 1614
# 6.비공감: 967
#
#
#
#
# 총 20 건 중 8 번째 리뷰 데이터를 수집합니다==============
# 1.별점: * :  1
# 2.리뷰내용: 과대평가 되는 영화의 대표적 예
# 3.작성자: 뽕휴(bbon****)
# 4.작성일자: 2013.06.09 13:59
# 5.공감: 1147
# 6.비공감: 576
#
#
#
#
# 총 20 건 중 9 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ****** :  6
# 2.리뷰내용: 사랑과 가족이라는 테마를 만들려다보니 작위적 감동과 인위적인 슬픔을 남발했음
# 3.작성자: ruby****
# 4.작성일자: 2013.07.22 01:50
# 5.공감: 832
# 6.비공감: 276
#
#
#
#
# 총 20 건 중 10 번째 리뷰 데이터를 수집합니다==============
# 1.별점: *** :  3
# 2.리뷰내용: 공권력에 무릎꿇는 무력함에 기분만 나빠지고 뭐가 순수한 슬픔인지도 모르겠다;; 그리고 너무 과도한 설정과 사건들. 배우들 연기력엔 찬사를 보내지만 영화로서의 작품성은 떨어지는 듯 보인다.
# 3.작성자: 모모아이(jsb4****)
# 4.작성일자: 2013.06.09 13:42
# 5.공감: 691
# 6.비공감: 242
#
#
#
#
# 총 20 건 중 11 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 40대 딸아이 아빤데 혼자 보다가 폭풍 눈물 생긴건 완전 산적인데...
# 3.작성자: sata****
# 4.작성일자: 2013.06.22 12:18
# 5.공감: 457
# 6.비공감: 132
#
#
#
#
# 총 20 건 중 12 번째 리뷰 데이터를 수집합니다==============
# 1.별점: * :  1
# 2.리뷰내용: 별로다 .. 너뮤 억지로  눈물 짜내기 영화같은데
# 3.작성자: 스마트(jesi****)
# 4.작성일자: 2013.07.13 10:20
# 5.공감: 932
# 6.비공감: 633
#
#
#
#
# 총 20 건 중 13 번째 리뷰 데이터를 수집합니다==============
# 1.별점: **** :  4
# 2.리뷰내용: 개연성 무시, 억지감성팔이, 눈물강요, 게다가 범죄미화까지.. 배우들이 아깝다 이딴영화가 천만이라니ㅜㅜ으
# 3.작성자: 림(rimi****)
# 4.작성일자: 2013.07.09 16:12
# 5.공감: 518
# 6.비공감: 242
#
#
#
#
# 총 20 건 중 14 번째 리뷰 데이터를 수집합니다==============
# 1.별점: **** :  4
# 2.리뷰내용: 초반 박신혜 법정씬에서 이미 영화끝남.남은 것은 해피엔딩이냐 새드엔딩이냐 ...
# 3.작성자: 당가(skll****)
# 4.작성일자: 2013.09.14 23:01
# 5.공감: 370
# 6.비공감: 151
#
#
#
#
# 총 20 건 중 15 번째 리뷰 데이터를 수집합니다==============
# 1.별점: *** :  3
# 2.리뷰내용: 글쎄... 이렇게 평점 높을 영화는 아닌거같다.
# 3.작성자: 가막새(rkak****)
# 4.작성일자: 2013.08.06 22:41
# 5.공감: 329
# 6.비공감: 127
#
#
#
#
# 총 20 건 중 16 번째 리뷰 데이터를 수집합니다==============
# 1.별점: **** :  4
# 2.리뷰내용: 눈물과 웃음을 동시에 강요한다. 억지로 짜내는 감정은 사람들에게 가슴으로 우려나오는 깊은 감동을 선사할수없다.
# 3.작성자: ghde****
# 4.작성일자: 2013.06.28 18:14
# 5.공감: 299
# 6.비공감: 105
#
#
#
#
# 총 20 건 중 17 번째 리뷰 데이터를 수집합니다==============
# 1.별점: * :  1
# 2.리뷰내용: 영화가 처음부터 판지스러웠으면 몰라도 현실적인설정으로 가다가 열기구 장면부터 너무 갑자기 판타지로돌변해서 몰입도를 떨어뜨리는듯...그리고 저는 마지막 슬픈장면은 너무 억지스럽다고 느꼈습니다... 저는 개인적으로 7~...
# 3.작성자: nhkuy47(dipd****)
# 4.작성일자: 2013.06.05 19:48
# 5.공감: 359
# 6.비공감: 166
#
#
#
#
# 총 20 건 중 18 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ******* :  7
# 2.리뷰내용: 약간 억지스러움... 기대 이하였음
# 3.작성자: 타락(tmdr****)
# 4.작성일자: 2013.06.03 23:47
# 5.공감: 418
# 6.비공감: 232
#
#
#
#
# 총 20 건 중 19 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 아니..ㅋㅋ 재미다 감동이다 이런거 못느껴서 점수 낮게 주는건 이해하는데ㅋㅋ 현실성 떨어진다 억지다는 뭔 개솔??ㅋㅋ 영화니까 당연한거 아냐?? 그럼 못사는 여자가 백만장자 만나서 신데렐라 인생역전은 말이되고??  ...
# 3.작성자: kick****
# 4.작성일자: 2013.05.29 21:27
# 5.공감: 374
# 6.비공감: 189
#
#
#
#
# 총 20 건 중 20 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 인상깊었다
# 3.작성자: 촹렐루야(losa****)
# 4.작성일자: 2013.07.20 23:58
# 5.공감: 313
# 6.비공감: 132
#
#
#
#
# ================================================================================
# 1.요청된 총 20 건의 리뷰 중에서 실제 크롤링 된 리뷰수는 20 건입니다
# 2.총 소요시간은 31.2 초 입니다
# 3.파일 저장 완료: txt 파일명 : c:\practice\2021-06-12-22-14-31-7번방의 선물\2021-06-12-22-14-31-7번방의 선물.txt
# 4.파일 저장 완료: csv 파일명 : c:\practice\2021-06-12-22-14-31-7번방의 선물\2021-06-12-22-14-31-7번방의 선물.csv
# 5.파일 저장 완료: xls 파일명 : c:\practice\2021-06-12-22-14-31-7번방의 선물\2021-06-12-22-14-31-7번방의 선물.xls
# ================================================================================
